# %%
# Импорт основного датасета 

import pandas as pd

file_path = 'reviews_output_with_id.csv'

data = pd.read_csv(file_path, encoding='UTF-8', delimiter=',')

data = data.dropna(subset=["ID", "Review Title", "Rating", "Review Text", "Date"])

data = data.drop_duplicates(subset=["ID"])

print(data.shape)
# Out:
# (2709, 5)

# %%
# очистка текста (приведение текста к нижнему регистру удаление символов не на кириллице)

import pandas as pd
import re
from nltk.corpus import stopwords
import nltk

nltk.download('stopwords')
russian_stopwords = stopwords.words('russian')

custom_stopwords = ["банк", "дом", "рф", "ао"]

all_stopwords = set(russian_stopwords + custom_stopwords)

def clear_text(text: str) -> str:
    clean_text = re.sub(r'[^А-Яа-яЁё]+', ' ', text).lower()
    return ' '.join(clean_text.split())

def clean_stop_words(text: str, all_stopwords: list) -> str:
    text = [word for word in text.split() if word not in all_stopwords]
    return ' '.join(text)

def preprocess_text(text: str, all_stopwords: list = all_stopwords) -> str:
    text = clear_text(text)
    text = clean_stop_words(text, all_stopwords)
    return text

data['Processed Text'] = data['Review Text'].apply(preprocess_text)

print(data)
# Out:
#         ID                     Review Title  Rating  \
# 0        1                     Хороший банк       5
# 1        2                Сделка по ипотеке       5
# 2        3                   Онлайн ипотека       5
# 3        4                    Отличный банк       5
# 4        5                   Оплата ипотеки       5
# ...    ...                              ...     ...
# 2704  2705     Очень медленное обслуживание       2
# 2705  2706              Качественная работа       4
# 2706  2707  Надо менять кадры или структуру       1
# 2707  2708           Платеж в Дельта-Кредит       1
# 2708  2709       Непростительная халатность       1
#
#                                             Review Text              Date  \
# 0     Являюсь клиентом с 2023 года. Ранее взяли ипот...  04.12.2024 10:53
# 1     Планировали купить жилой дом по программе семе...  04.12.2024 09:04
# 2     Давно мечтала обеспечить дочку квартирой в Мос...  27.11.2024 20:56
# 3     27 ноября 2024 года приехал на оформление ипот...  27.11.2024 15:32
# 4     21.11.24 пришла для оплаты ипотеки в офис на С...  21.11.2024 17:09
# ...                                                 ...               ...
# 2704  10.09.13 закрыл ипотечный кредит в данном банк...  25.09.2013 09:42
# 2705  Хочу отметить качественную работу отдела инфор...  10.09.2013 07:54
# 2706  Добрый день! Такой работы от банковских сотруд...  24.10.2011 22:37
# 2707  .466 Приходится делать платежи по ипотеке в Де...  14.10.2006 11:03
# 2708  .466 Как заёмщик Городского Ипотечного Банка д...  23.01.2006 15:27
#
#                                          Processed Text
# 0     являюсь клиентом года ранее взяли ипотеку банк...
# 1     планировали купить жилой программе семейная ип...
# 2     давно мечтала обеспечить дочку квартирой москв...
# 3     ноября года приехал оформление ипотечного кред...
# 4     пришла оплаты ипотеки офис семеновской набереж...
# ...                                                 ...
# 2704  закрыл ипотечный кредит данном банке попал сво...
# 2705  хочу отметить качественную работу отдела инфор...
# 2706  добрый день работы банковских сотрудников виде...
# 2707  приходится делать платежи ипотеке дельта креди...
# 2708  заёмщик городского ипотечного банка должна пог...
#
# [2709 rows x 6 columns]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/semenzidkov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# лемматизация текста 

import pandas as pd
import re
from nltk.corpus import stopwords
import nltk
from pymystem3 import Mystem

# Инициализация Mystem
mystem = Mystem()

# Загрузка стоп-слов для русского языка
nltk.download('stopwords')
russian_stopwords = stopwords.words('russian')

custom_stopwords = ["банк", "дом", "рф", "ао"]

all_stopwords = set(russian_stopwords + custom_stopwords)

# Функция для очистки текста
def clear_text(text: str) -> str:
    """
    Очищает текст, оставляя только кириллические символы и приводя слова к нижнему регистру.
    """
    clean_text = re.sub(r'[^А-Яа-яЁё]+', ' ', text).lower()
    return ' '.join(clean_text.split())

# Функция для удаления стоп-слов
def clean_stop_words(text: str, all_stopwords: list) -> str:
    """
    Удаляет стоп-слова из текста.
    """
    text = [word for word in text.split() if word not in all_stopwords]
    return ' '.join(text)

# Функция для лемматизации текста с помощью pymystem3
def lemmatize_text(text: str) -> str:
    """
    Лемматизация текста с использованием pymystem3.
    """
    lemmatized_text = ''.join(mystem.lemmatize(text))
    return lemmatized_text.strip()

# Полная обработка текста
def preprocess_text(text: str, all_stopwords: list = all_stopwords) -> str:
    """
    Полная обработка текста: очистка, удаление стоп-слов, лемматизация.
    """
    text = clear_text(text)  # Очистка текста
    text = clean_stop_words(text, all_stopwords)  # Удаление стоп-слов
    text = lemmatize_text(text)  # Лемматизация
    return text

# Пример DataFrame

# Применение полной обработки текста к столбцу 'Review Text'
data['Processed Text'] = data['Review Text'].apply(preprocess_text)

# Результат
print(data)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/semenzidkov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#         ID                     Review Title  Rating  \
# 0        1                     Хороший банк       5
# 1        2                Сделка по ипотеке       5
# 2        3                   Онлайн ипотека       5
# 3        4                    Отличный банк       5
# 4        5                   Оплата ипотеки       5
# ...    ...                              ...     ...
# 2704  2705     Очень медленное обслуживание       2
# 2705  2706              Качественная работа       4
# 2706  2707  Надо менять кадры или структуру       1
# 2707  2708           Платеж в Дельта-Кредит       1
# 2708  2709       Непростительная халатность       1
#
#                                             Review Text              Date  \
# 0     Являюсь клиентом с 2023 года. Ранее взяли ипот...  04.12.2024 10:53
# 1     Планировали купить жилой дом по программе семе...  04.12.2024 09:04
# 2     Давно мечтала обеспечить дочку квартирой в Мос...  27.11.2024 20:56
# 3     27 ноября 2024 года приехал на оформление ипот...  27.11.2024 15:32
# 4     21.11.24 пришла для оплаты ипотеки в офис на С...  21.11.2024 17:09
# ...                                                 ...               ...
# 2704  10.09.13 закрыл ипотечный кредит в данном банк...  25.09.2013 09:42
# 2705  Хочу отметить качественную работу отдела инфор...  10.09.2013 07:54
# 2706  Добрый день! Такой работы от банковских сотруд...  24.10.2011 22:37
# 2707  .466 Приходится делать платежи по ипотеке в Де...  14.10.2006 11:03
# 2708  .466 Как заёмщик Городского Ипотечного Банка д...  23.01.2006 15:27
#
#                                          Processed Text
# 0     являться клиент год ранее взять ипотека банк п...
# 1     планировать купить жилой программа семейный ип...
# 2     давно мечтать обеспечивать дочка квартира моск...
# 3     ноябрь год приезжать оформление ипотечный кред...
# 4     приходить оплата ипотека офис семеновский набе...
# ...                                                 ...
# 2704  закрывать ипотечный кредит данный банк попадат...
# 2705  хотеть отмечать качественный работа отдел инфо...
# 2706  добрый день работа банковский сотрудник видеть...
# 2707  приходиться делать платеж ипотека дельта креди...
# 2708  заемщик городской ипотечный банк должный погаш...
#
# [2709 rows x 6 columns]

# %%
# 5-6 ngrams 

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# Функция для определения наиболее частотных слов
def get_top_words(texts, top_n=10):
    """
    Определяет наиболее частотные слова в текстах.
    
    :param texts: Список текстов.
    :param top_n: Количество наиболее частотных слов.
    :return: DataFrame с частотными словами.
    """
    # Инициализация CountVectorizer
    vectorizer = CountVectorizer(ngram_range=(5,6))
    word_counts = vectorizer.fit_transform(texts)

    # Получение суммарного количества слов
    total_counts = word_counts.sum(axis=0).A1
    words = vectorizer.get_feature_names_out()

    # Создание DataFrame с частотами
    word_freq = pd.DataFrame({'Word': words, 'Frequency': total_counts})
    word_freq = word_freq.sort_values(by='Frequency', ascending=False).head(top_n)
    return word_freq

# Получение наиболее частотных слов
top_words = get_top_words(data['Processed Text'], top_n=10)

# Вывод результатов
print("Наиболее частотные слова:")
print(top_words)
# Out:
# Наиболее частотные слова:
#                                                     Word  Frequency
# 69520     прекращение ипотека полный исполнение денежный         17
# 69521  прекращение ипотека полный исполнение денежный...         17
# 31309   ипотека полный исполнение денежный обязательство         17
# 26874    заявление прекращение ипотека полный исполнение         15
# 26875  заявление прекращение ипотека полный исполнени...         14
# 11187     выражать огромный благодарность сотрудник банк          9
# 65176        полный досрочный погашение ипотечный кредит          8
# 63167  подавать заявление прекращение ипотека полный ...          7
# 63166      подавать заявление прекращение ипотека полный          7
# 92783       хотеть выражать благодарность сотрудник банк          7

# %%
# Построение графиков

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Функция для определения частотных слов
def get_word_frequencies(texts):
    vectorizer = CountVectorizer(ngram_range=(5,6))
    word_counts = vectorizer.fit_transform(texts)
    words = vectorizer.get_feature_names_out()
    frequencies = word_counts.sum(axis=0).A1
    return dict(zip(words, frequencies))

# Получение частотных слов
word_frequencies = get_word_frequencies(data['Processed Text'])

# Построение облака слов
wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='Greens')
wordcloud.generate_from_frequencies(word_frequencies)

# Отображение облака слов
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Убираем оси
plt.title("Облако самых частотных слов", fontsize=16)
plt.show()

# Построение гистограммы самых частотных слов
top_words = pd.DataFrame(word_frequencies.items(), columns=["Word", "Frequency"]).sort_values(by="Frequency", ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top_words["Word"], top_words["Frequency"])
plt.title("Топ-10 самых частотных слов", fontsize=16)
plt.xlabel("Слова")
plt.ylabel("Частота")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation


# Преобразование текстов в Bag-of-Words (матрица частот)
vectorizer = CountVectorizer(ngram_range=(5,6))
text_bow = vectorizer.fit_transform(data['Processed Text'])

# Определение количества тем
n_topics = 10

# Обучение модели LDA
lda_model = LatentDirichletAllocation(
    n_components=n_topics,
    topic_word_prior=0.01,
    random_state=42,
    max_iter=200,
    learning_method='batch')
lda_model.fit(text_bow)

# Функция для отображения ключевых слов в темах
def print_topics(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Тема {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))

# Печать ключевых слов для каждой темы
n_top_words = 1
print("Ключевые слова в темах:")
print_topics(lda_model, vectorizer.get_feature_names_out(), n_top_words)

# Получение распределения тем для каждого документа
doc_topic_distributions = lda_model.transform(text_bow)
data['Dominant Topic'] = doc_topic_distributions.argmax(axis=1) + 1  # Номер темы (1, 2, ...)
print("\nДокументы с их доминирующими темами:")
print(data[['ID', 'Processed Text', 'Dominant Topic']])
# Out:
# Ключевые слова в темах:
# Тема 1:
# прекращение ипотека полный исполнение денежный обязательство
# Тема 2:
# заявление прекращение ипотека полный исполнение
# Тема 3:
# проконсультировать оформление сделка освещать возможный
# Тема 4:
# рефинансирование ипотека отправлять необходимый документ
# Тема 5:
# прекращение ипотека полный исполнение денежный обязательство
# Тема 6:
# полный досрочный погашение ипотечный кредит
# Тема 7:
# господдержка многодетный семья размер тысяча
# Тема 8:
# хотеть выражать благодарность сотрудник банк
# Тема 9:
# добрый день мочь получать закладная
# Тема 10:
# погашение ипотека написать заявление выдача
#
# Документы с их доминирующими темами:
#         ID                                     Processed Text  Dominant Topic
# 0        1  являться клиент год ранее взять ипотека банк п...               9
# 1        2  планировать купить жилой программа семейный ип...               9
# 2        3  давно мечтать обеспечивать дочка квартира моск...              10
# 3        4  ноябрь год приезжать оформление ипотечный кред...               7
# 4        5  приходить оплата ипотека офис семеновский набе...               7
# ...    ...                                                ...             ...
# 2704  2705  закрывать ипотечный кредит данный банк попадат...              10
# 2705  2706  хотеть отмечать качественный работа отдел инфо...               5
# 2706  2707  добрый день работа банковский сотрудник видеть...               1
# 2707  2708  приходиться делать платеж ипотека дельта креди...               1
# 2708  2709  заемщик городской ипотечный банк должный погаш...               7
#
# [2709 rows x 3 columns]
